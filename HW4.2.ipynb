# %%
# Import Libraries
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
# Check the current directory where the Python program is executing from
print(f"Current Working Directory: {Path.cwd()}")
# Out:
# Current Working Directory: /Users/wilsonquizhpi/Homework-unite-4

# %%
# Read CSV
sp500_history_path = Path('sp500_history.csv')
algo_returns_path = Path('algo_returns.csv')
whale_retuns_path = Path('whale_returns.csv')

# %%
sp500_history_df = pd.read_csv(sp500_history_path, index_col="Date")
sp500_history_df.head()
# Out:
#               Close
# Date
# 23-Apr-19  $2933.68
# 22-Apr-19  $2907.97
# 18-Apr-19  $2905.03
# 17-Apr-19  $2900.45
# 16-Apr-19  $2907.06

# %%
sp500_history_df['Close'] = sp500_history_df['Close].astype('float')
sp500_history_df.head()
# Out:
#             S&P 500
# Date
# 23-Apr-19  $2933.68
# 22-Apr-19  $2907.97
# 18-Apr-19  $2905.03
# 17-Apr-19  $2900.45
# 16-Apr-19  $2907.06

# %%
sp500_history_df['S&P 500'] = sp500_history_df['S&P 500'].str.replace("$", "")
sp500_history_df.head()
# Out:
# /var/folders/yw/s7_xdw_d6p9231wbk6jwlsvm0000gn/T/ipykernel_3095/1964992734.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_history_df['S&P 500'] = sp500_history_df['S&P 500'].str.replace("$", "")
#            S&P 500
# Date
# 23-Apr-19  2933.68
# 22-Apr-19  2907.97
# 18-Apr-19  2905.03
# 17-Apr-19  2900.45
# 16-Apr-19  2907.06

# %%
from datetime import datetime
sp500_history_df.index = pd.to_datetime(sp500_history_df.index)
sp500_history_df.index = sp500_history_df.index.strftime('%y/%m/%d')
sp500_history_df.head()
# Out:
#           S&P 500
# Date
# 19/04/23  2933.68
# 19/04/22  2907.97
# 19/04/18  2905.03
# 19/04/17  2900.45
# 19/04/16  2907.06

# %%
algo_returns_df = pd.read_csv(algo_returns_path, index_col="Date")
algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
from datetime import datetime
algo_returns_df.index = pd.to_datetime(algo_returns_df.index)
algo_returns_df.index = algo_returns_df.index.strftime('%y/%m/%d')
algo_returns_df.head()
# Out:
#             Algo 1  Algo 2
# Date
# 14/05/28  0.001745     NaN
# 14/05/29  0.003978     NaN
# 14/05/30  0.004464     NaN
# 14/06/02  0.005692     NaN
# 14/06/03  0.005292     NaN

# %%
whale_retuns_df = pd.read_csv(whale_retuns_path, index_col="Date")
whale_retuns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
from datetime import datetime
whale_retuns_df.index = pd.to_datetime(whale_retuns_df.index)
whale_retuns_df.index = whale_retuns_df.index.strftime('%y/%m/%d')
whale_retuns_df.head()
# Out:
#           SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 15/03/02                        NaN                 NaN
# 15/03/03                  -0.001266           -0.004981
# 15/03/04                   0.002230            0.003241
# 15/03/05                   0.004016            0.004076
# 15/03/06                  -0.007905           -0.003574
#
#           TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 15/03/02                          NaN                     NaN
# 15/03/03                    -0.000496               -0.006569
# 15/03/04                    -0.002534                0.004213
# 15/03/05                     0.002355                0.006726
# 15/03/06                    -0.008481               -0.013098

# %%
# Check for nulls
sp500_history_df.isnull().sum
#Drop missing values
sp500_history_df = sp500_history_df.dropna()

# %%
# Check for nulls
algo_returns_df.isnull().sum
#Drop missing values
algo_returns_df = algo_returns_df.dropna()

# %%
# Check for nulls
whale_retuns_df.isnull().sum
#Drop missing values
whale_retuns_df = whale_retuns_df.dropna()

# %%
sp500_history_daily_return = sp500_history_df.pct_change()
sp500_history_daily_return.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/yw/s7_xdw_d6p9231wbk6jwlsvm0000gn/T/ipykernel_3095/3514137714.py in <module>
# ----> 1 sp500_history_daily_return = sp500_history_df.pct_change()
#       2 sp500_history_daily_return.head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10163         shifted = data.shift(periods=periods, freq=freq, axis=axis, **kwargs)
#   10164         # Unsupported left operand type for / ("FrameOrSeries")
# > 10165         rs = data / shifted - 1  # type: ignore[operator]
#   10166         if freq is not None:
#   10167             # Shift method is implemented differently when freq is not None
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __truediv__(self, other)
#     114     @unpack_zerodim_and_defer("__truediv__")
#     115     def __truediv__(self, other):
# --> 116         return self._arith_method(other, operator.truediv)
#     117
#     118     @unpack_zerodim_and_defer("__rtruediv__")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    6903             # TODO operate_blockwise expects a manager of the same type
#    6904             with np.errstate(all="ignore"):
# -> 6905                 bm = self._mgr.operate_blockwise(
#    6906                     # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    6907                     # incompatible type "Union[ArrayManager, BlockManager]"; expected
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in operate_blockwise(self, other, array_op)
#    1301         Apply array_op blockwise with another (aligned) BlockManager.
#    1302         """
# -> 1303         return operate_blockwise(self, other, array_op)
#    1304
#    1305     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/ops.py in operate_blockwise(left, right, array_op)
#      55     res_blks: list[Block] = []
#      56     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 57         res_values = array_op(lvals, rvals)
#      58         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      59             res_values = res_values.reshape(1, -1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     110         # See GH#5284, GH#5035, GH#19448 for historical reference
#     111         if mask.any():
# --> 112             result[mask] = op(xrav[mask], yrav[mask])
#     113
#     114     else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
